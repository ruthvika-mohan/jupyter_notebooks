# %%
import pandas as pd
import numpy as np 
from IPython.display import display
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\personal\\willow_ai\\marshal_ai_solutions\\data_w_new_features\\unclean_features.csv",header = 0,low_memory = False)

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 32 columns):
#  #   Column                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                    --------------  -----
#  0   In the past 7 days, which of the following printed/paper issues did you read of The Indianapolis Star...?                                                 4500 non-null   object
#  1   Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days?  Did you read...?                                 4500 non-null   object
# ...

# %% [markdown]
# ## In the past 7 days, which of the following printed/paper issues did you read of The Indianapolis Star...?

# %%
for index, row in df.iterrows():
    l = str(row['In the past 7 days, which of the following printed/paper issues did you read of The Indianapolis Star...?']).split(",")
    #print(l)
    if('Sunday Issue' in l):
        #print("hm")
        df.loc[index, 'In the past 7 days, did you read Sunday issue of The Indianapolis Star...?'] = "Yes" 
    else: 
        df.loc[index, 'In the past 7 days, did you read Sunday issue of The Indianapolis Star...?'] = "No" 
    if('Monday Issue' in l):
        #print("hm")
        df.loc[index, 'In the past 7 days, did you read Monday issue of The Indianapolis Star...?'] = "Yes"
    else: 
        df.loc[index, 'In the past 7 days, did you read Monday issue of The Indianapolis Star...?'] = "No" 

        
    if('Tuesday Issue' in l):
        #print("hm")
        df.loc[index, 'In the past 7 days, did you read Tuesday issue of The Indianapolis Star...?'] = "Yes"
    else: 
        df.loc[index, 'In the past 7 days, did you read Tuesday issue of The Indianapolis Star...?'] = "No" 

    if('Wednesday Issue' in l):
        #print("hm")
        df.loc[index, 'In the past 7 days, did you read Wednesday issue of The Indianapolis Star...?'] = "Yes" 
    else: 
        df.loc[index, 'In the past 7 days, did you read Wednesday issue of The Indianapolis Star...?'] = "No" 

    if('Thursday Issue' in l):
        #print("hm")
        df.loc[index, 'In the past 7 days, did you read Thursday issue of The Indianapolis Star...?'] = "Yes"
    else: 
        df.loc[index, 'In the past 7 days, did you read Thursday issue of The Indianapolis Star...?'] = "No" 

    if('Friday Issue' in l):
        #print("hm")
        df.loc[index, 'In the past 7 days, did you read Friday issue of The Indianapolis Star...?'] = "Yes"
    else: 
        df.loc[index, 'In the past 7 days, did you read Friday issue of The Indianapolis Star...?'] = "No" 

    if('Saturday Issue' in l):
        #print("hm")
        df.loc[index, 'In the past 7 days, did you read Saturday issue of The Indianapolis Star...?'] = "Yes"
    else: 
        df.loc[index, 'In the past 7 days, did you read Saturday issue of The Indianapolis Star...?'] = "No"

# %%
df.head(5)
# Out:
#   In the past 7 days, which of the following printed/paper issues did you read of The Indianapolis Star...?  \
# 0  Sunday Issue, Monday Issue, Tuesday Issue, Wed...
# 1  Sunday Issue, Monday Issue, Tuesday Issue, Wed...
# 2                                 Did not read paper
# 3                       Sunday Issue, Thursday Issue
# 4  Sunday Issue, Monday Issue, Tuesday Issue, Wed...
#
#   Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days?  Did you read...?  \
# 0  Main News, Metro + State, Sports, Indy Sunday,...
# 1  Main News, Metro + State, Sports, Indy Sunday,...
# 2                                      None of these
# 3  Main News, Metro + State, Sports, Extra, Indy ...
# 4  Main News, Metro + State, Sports, Extra, Indy ...
#
#   Which of the following items have you shopped for on the internet in the past 12 months?  \
# 0                       1Do not have Internet Access
# ...

# %% [markdown]
# ## Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days?  Did you read...?

# %%
for index, row in df.iterrows():
    l = str(row['Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days?  Did you read...?']).split(',')
    if(len(l)>0):
        if ('Main News' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Main News?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Main News?'] = "No"
        if ('Metro + State' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Metro + State?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Metro + State?'] = "No"
        if ('Sports' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Sports?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Sports'] = "No"
            
        if ('Extra' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Extra?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Extra?'] = "No"
            
        if ('Indy Sunday' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Indy Sunday?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Indy Sunday?'] = "No"
            
        if ('Homefinder.com' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Homefinder.com?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Homefinder.com'] = "No"
            
        if ('cars.com' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read cars.com?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read cars.com?'] = "No"
        if ('Market Place (Classifieds)' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Classifieds?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Classifieds?'] = "No"
            
        if ('Local Section like East side/Fishers/Noblesville/South Side/West side' in l):
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Local Section?'] = "Yes"
        else:
            df[index, 'Which of the following printed/paper sections of The Indianapolis Star did you read in the past 7 days? Did you read Local Section?'] = "No"

    
            





    
    
    #Main News	 	 Sports	 Extra	 Indy Sunday	 Homefinder.com	 cars.com	 Market Place (Classifieds)	 Local Section like East side/Fishers/Noblesville/South Side/West side
